# %% [markdown]
# # One question asked by the reviewers is how do we ensure that the traininng loss is the same
# # Here, we try to extend the training time to 2 times longer
# # What we see is that the training loss Simpson plot and the BLEU Simpson plot almost does not change

# %% [markdown]
# # In the plot, the "new points" are the ones that deviate from the main cluster. Look at the "rightmost" clusters. Those are for the lr=0.0625 case. Then, look at num samples = 160000 (orange cluster), 320000 (red cluster), 640000 (purple cluster). For each cluster, there is a single point that is slightly shifted. That is the case when training the model for longer time

# %%
from IPython.display import Image
Image(filename='Longer_training_test_BLEU.png')

# %%
Image(filename='Longer_training_train_loss.png')
