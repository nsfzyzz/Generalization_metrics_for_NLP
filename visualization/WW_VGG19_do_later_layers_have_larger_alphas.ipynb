# %% [markdown]
# # We try to see if the later layers of NN have larger alphas. It seems that they don't

# %%
import torch
model = torch.hub.load('pytorch/vision:v0.10.0', 'vgg19', pretrained=True)
# Out:
# Using cache found in /home/eecs/yyaoqing/.cache/torch/hub/pytorch_vision_v0.10.0
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /home/eecs/yyaoqing/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
#   0%|          | 0.00/548M [00:00<?, ?B/s]

# %%
import weightwatcher as ww

# %%
watcher = ww.WeightWatcher(model=model)
analyze = watcher.analyze(plot=True)
summary = watcher.get_summary()
# Out:
# INFO:weightwatcher:
#
# python      version 3.8.3 (default, Jul  2 2020, 16:21:59)
# [GCC 7.3.0]
# numpy       version 1.18.5
# tensforflow version 2.3.1
# keras       version 2.4.0
# INFO:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 0 None has no weights
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 1 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (64, 3, 3, 3)
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape detected: 64x3 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=64 M=3 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 64 max evals None
# INFO:weightwatcher:LAYER: 2 8  : <class 'torch.nn.modules.conv.Conv2d'>
# DEBUG:weightwatcher:apply ESD  on Layer 2 None
# DEBUG:weightwatcher:running SVD on Layer 2 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 3)  n_comp = 3
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 3)  n_comp = 3
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 3)  n_comp = 3
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 3)  n_comp = 3
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 3)  n_comp = 3
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 3)  n_comp = 3
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 3)  n_comp = 3
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 3)  n_comp = 3
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 3)  n_comp = 3
# DEBUG:weightwatcher:fitting power law on 27 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:1178: RuntimeWarning: overflow encountered in double_scalars
#   return (self.alpha-1) * self.xmin**(self.alpha-1)
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:825: RuntimeWarning: invalid value encountered in multiply
#   likelihoods = f*C
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 3 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (64, 64, 3, 3)
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape detected: 64x64 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=64 M=64 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 64 max evals None
# INFO:weightwatcher:LAYER: 4 8  : <class 'torch.nn.modules.conv.Conv2d'>
# DEBUG:weightwatcher:apply ESD  on Layer 4 None
# DEBUG:weightwatcher:running SVD on Layer 4 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 64)  n_comp = 64
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 64)  n_comp = 64
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 64)  n_comp = 64
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 64)  n_comp = 64
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 64)  n_comp = 64
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 64)  n_comp = 64
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 64)  n_comp = 64
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 64)  n_comp = 64
# DEBUG:weightwatcher:Running full SVD:  W.shape=(64, 64)  n_comp = 64
# DEBUG:weightwatcher:fitting power law on 576 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 5 None has no weights
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 6 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (128, 64, 3, 3)
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape detected: 128x64 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=128 M=64 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 128 max evals None
# INFO:weightwatcher:LAYER: 7 8  : <class 'torch.nn.modules.conv.Conv2d'>
# DEBUG:weightwatcher:apply ESD  on Layer 7 None
# DEBUG:weightwatcher:running SVD on Layer 7 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 64)  n_comp = 64
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 64)  n_comp = 64
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 64)  n_comp = 64
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 64)  n_comp = 64
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 64)  n_comp = 64
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 64)  n_comp = 64
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 64)  n_comp = 64
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 64)  n_comp = 64
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 64)  n_comp = 64
# DEBUG:weightwatcher:fitting power law on 576 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 8 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (128, 128, 3, 3)
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape detected: 128x128 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=128 M=128 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 128 max evals None
# INFO:weightwatcher:LAYER: 9 8  : <class 'torch.nn.modules.conv.Conv2d'>
# DEBUG:weightwatcher:apply ESD  on Layer 9 None
# DEBUG:weightwatcher:running SVD on Layer 9 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 128)  n_comp = 128
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 128)  n_comp = 128
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 128)  n_comp = 128
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 128)  n_comp = 128
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 128)  n_comp = 128
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 128)  n_comp = 128
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 128)  n_comp = 128
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 128)  n_comp = 128
# DEBUG:weightwatcher:Running full SVD:  W.shape=(128, 128)  n_comp = 128
# DEBUG:weightwatcher:fitting power law on 1152 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 10 None has no weights
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 11 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (256, 128, 3, 3)
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape detected: 256x128 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=256 M=128 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 256 max evals None
# INFO:weightwatcher:LAYER: 12 8  : <class 'torch.nn.modules.conv.Conv2d'>
# DEBUG:weightwatcher:apply ESD  on Layer 12 None
# DEBUG:weightwatcher:running SVD on Layer 12 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 128)  n_comp = 128
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 128)  n_comp = 128
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 128)  n_comp = 128
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 128)  n_comp = 128
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 128)  n_comp = 128
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 128)  n_comp = 128
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 128)  n_comp = 128
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 128)  n_comp = 128
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 128)  n_comp = 128
# DEBUG:weightwatcher:fitting power law on 1152 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 13 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (256, 256, 3, 3)
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape detected: 256x256 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=256 M=256 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 256 max evals None
# INFO:weightwatcher:LAYER: 14 8  : <class 'torch.nn.modules.conv.Conv2d'>
# DEBUG:weightwatcher:apply ESD  on Layer 14 None
# DEBUG:weightwatcher:running SVD on Layer 14 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:fitting power law on 2304 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 15 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (256, 256, 3, 3)
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape detected: 256x256 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=256 M=256 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 256 max evals None
# INFO:weightwatcher:LAYER: 16 8  : <class 'torch.nn.modules.conv.Conv2d'>
# DEBUG:weightwatcher:apply ESD  on Layer 16 None
# DEBUG:weightwatcher:running SVD on Layer 16 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:fitting power law on 2304 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 17 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (256, 256, 3, 3)
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape detected: 256x256 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=256 M=256 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 256 max evals None
# INFO:weightwatcher:LAYER: 18 8  : <class 'torch.nn.modules.conv.Conv2d'>
# DEBUG:weightwatcher:apply ESD  on Layer 18 None
# DEBUG:weightwatcher:running SVD on Layer 18 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(256, 256)  n_comp = 256
# DEBUG:weightwatcher:fitting power law on 2304 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 19 None has no weights
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 20 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (512, 256, 3, 3)
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape detected: 512x256 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=512 M=256 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 512 max evals None
# INFO:weightwatcher:LAYER: 21 8  : <class 'torch.nn.modules.conv.Conv2d'>
# DEBUG:weightwatcher:apply ESD  on Layer 21 None
# DEBUG:weightwatcher:running SVD on Layer 21 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 256)  n_comp = 256
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 256)  n_comp = 256
# DEBUG:weightwatcher:fitting power law on 2304 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 22 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (512, 512, 3, 3)
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape detected: 512x512 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=512 M=512 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 512 max evals None
# INFO:weightwatcher:LAYER: 23 8  : <class 'torch.nn.modules.conv.Conv2d'>
# DEBUG:weightwatcher:apply ESD  on Layer 23 None
# DEBUG:weightwatcher:running SVD on Layer 23 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:fitting power law on 4608 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 24 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (512, 512, 3, 3)
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape detected: 512x512 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=512 M=512 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 512 max evals None
# INFO:weightwatcher:LAYER: 25 8  : <class 'torch.nn.modules.conv.Conv2d'>
# DEBUG:weightwatcher:apply ESD  on Layer 25 None
# DEBUG:weightwatcher:running SVD on Layer 25 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:fitting power law on 4608 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 26 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (512, 512, 3, 3)
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape detected: 512x512 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=512 M=512 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 512 max evals None
# INFO:weightwatcher:LAYER: 27 8  : <class 'torch.nn.modules.conv.Conv2d'>
# DEBUG:weightwatcher:apply ESD  on Layer 27 None
# DEBUG:weightwatcher:running SVD on Layer 27 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:fitting power law on 4608 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 28 None has no weights
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 29 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (512, 512, 3, 3)
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape detected: 512x512 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=512 M=512 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 512 max evals None
# INFO:weightwatcher:LAYER: 30 8  : <class 'torch.nn.modules.conv.Conv2d'>
# DEBUG:weightwatcher:apply ESD  on Layer 30 None
# DEBUG:weightwatcher:running SVD on Layer 30 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:fitting power law on 4608 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 31 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (512, 512, 3, 3)
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape detected: 512x512 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=512 M=512 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 512 max evals None
# INFO:weightwatcher:LAYER: 32 8  : <class 'torch.nn.modules.conv.Conv2d'>
# DEBUG:weightwatcher:apply ESD  on Layer 32 None
# DEBUG:weightwatcher:running SVD on Layer 32 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:fitting power law on 4608 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 33 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (512, 512, 3, 3)
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape detected: 512x512 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=512 M=512 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 512 max evals None
# INFO:weightwatcher:LAYER: 34 8  : <class 'torch.nn.modules.conv.Conv2d'>
# DEBUG:weightwatcher:apply ESD  on Layer 34 None
# DEBUG:weightwatcher:running SVD on Layer 34 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:fitting power law on 4608 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 35 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (512, 512, 3, 3)
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape detected: 512x512 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=512 M=512 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 512 max evals None
# INFO:weightwatcher:LAYER: 36 8  : <class 'torch.nn.modules.conv.Conv2d'>
# DEBUG:weightwatcher:apply ESD  on Layer 36 None
# DEBUG:weightwatcher:running SVD on Layer 36 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:Running full SVD:  W.shape=(512, 512)  n_comp = 512
# DEBUG:weightwatcher:fitting power law on 4608 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 37 None has no weights
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 38 None has no weights
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 39 None has no weights
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 40 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (4096, 25088)
# DEBUG:weightwatcher:layer_supported  N 25088 max evals None
# INFO:weightwatcher:LAYER: 41 2  : <class 'torch.nn.modules.linear.Linear'>
# DEBUG:weightwatcher:apply ESD  on Layer 41 None
# DEBUG:weightwatcher:running SVD on Layer 41 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(4096, 25088)  n_comp = 4096
# DEBUG:weightwatcher:fitting power law on 4096 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 42 None has no weights
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 43 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (4096, 4096)
# DEBUG:weightwatcher:layer_supported  N 4096 max evals None
# INFO:weightwatcher:LAYER: 44 2  : <class 'torch.nn.modules.linear.Linear'>
# DEBUG:weightwatcher:apply ESD  on Layer 44 None
# DEBUG:weightwatcher:running SVD on Layer 44 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(4096, 4096)  n_comp = 4096
# DEBUG:weightwatcher:fitting power law on 4096 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 45 None has no weights
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 46 None has no weights
# DEBUG:weightwatcher:Linear weights shape  len(w)1 type(w)<class 'list'>  w.shape (1000, 4096)
# DEBUG:weightwatcher:layer_supported  N 4096 max evals None
# INFO:weightwatcher:LAYER: 47 2  : <class 'torch.nn.modules.linear.Linear'>
# DEBUG:weightwatcher:apply ESD  on Layer 47 None
# DEBUG:weightwatcher:running SVD on Layer 47 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(1000, 4096)  n_comp = 1000
# DEBUG:weightwatcher:fitting power law on 1000 eigenvalues
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# /home/eecs/yyaoqing/anaconda3/lib/python3.8/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /

# %%
print(analyze)
# Out:
#    layer_id  name         D       M        N      alpha  alpha_weighted  \
# 0         2  None  0.200768     3.0     64.0   2.691829        2.156662
# 1         4  None  0.143430    64.0     64.0   2.512862        0.690039
# 2         7  None  0.069853    64.0    128.0   5.568418        2.390792
# 3         9  None  0.129767   128.0    128.0  15.549984        0.716672
# 4        12  None  0.064503   128.0    256.0   3.886798        1.280928
# 5        14  None  0.087450   256.0    256.0   3.129077        0.262973
# 6        16  None  0.084917   256.0    256.0   2.968370        0.445415
# 7        18  None  0.040751   256.0    256.0   3.660554        1.131943
# 8        21  None  0.082360   256.0    512.0   3.619139        0.648295
# 9        23  None  0.043220   512.0    512.0   3.357673        0.797141
# 10       25  None  0.031346   512.0    512.0   3.462761        1.135959
# 11       27  None  0.032033   512.0    512.0   3.432073        1.430029
# 12       30  None  0.062095   512.0    512.0   3.752644        0.325526
# 13       32  None  0.040404   512.0    512.0   3.608050        0.491134
# 14       34  None  0.032994   512.0    512.0   3.552487        0.846939
# 15       36  None  0.057820   512.0    512.0   3.849090        1.325744
# 16       41  None  0.024841  4096.0  25088.0   2.271499        3.227122
# 17       44  None  0.031326  4096.0   4096.0   2.187923        3.591574
# 18       47  None  0.037037  1000.0   4096.0   2.071480        3.570230
#
#     has_esd  lambda_max         layer_type  ...  num_evals  num_pl_spikes  \
# 0       1.0    6.326864  LAYER_TYPE.CONV2D  ...       27.0           16.0
# 1       1.0    1.881928  LAYER_TYPE.CONV2D  ...      576.0           70.0
# 2       1.0    2.687501  LAYER_TYPE.CONV2D  ...      576.0           16.0
# 3       1.0    1.111958  LAYER_TYPE.CONV2D  ...     1152.0            9.0
# 4       1.0    2.135791  LAYER_TYPE.CONV2D  ...     1152.0           51.0
# 5       1.0    1.213505  LAYER_TYPE.CONV2D  ...     2304.0          176.0
# 6       1.0    1.412713  LAYER_TYPE.CONV2D  ...     2304.0          182.0
# 7       1.0    2.038108  LAYER_TYPE.CONV2D  ...     2304.0           84.0
# 8       1.0    1.510531  LAYER_TYPE.CONV2D  ...     2304.0          135.0
# 9       1.0    1.727463  LAYER_TYPE.CONV2D  ...     4608.0          238.0
# 10      1.0    2.128385  LAYER_TYPE.CONV2D  ...     4608.0          191.0
# 11      1.0    2.610154  LAYER_TYPE.CONV2D  ...     4608.0          240.0
# 12      1.0    1.221084  LAYER_TYPE.CONV2D  ...     4608.0          200.0
# 13      1.0    1.368112  LAYER_TYPE.CONV2D  ...     4608.0          216.0
# 14      1.0    1.731440  LAYER_TYPE.CONV2D  ...     4608.0          245.0
# 15      1.0    2.210195  LAYER_TYPE.CONV2D  ...     4608.0          372.0
# 16      1.0   26.345205   LAYER_TYPE.DENSE  ...     4096.0         1932.0
# 17      1.0   43.807182   LAYER_TYPE.DENSE  ...     4096.0         1150.0
# 18      1.0   52.907377   LAYER_TYPE.DENSE  ...     1000.0          418.0
#
#     rank_loss   rf     sigma  spectral_norm  stable_rank    sv_max       xmax  \
# 0         0.0  9.0  0.422957       6.326864     8.795783  2.515326   6.326864
# 1         0.0  9.0  0.180822       1.881928    30.488629  1.371834   1.881928
# 2         0.0  9.0  1.142104       2.687501    32.511587  1.639360   2.687501
# 3         0.0  9.0  4.849995       1.111958    96.782274  1.054494   1.111958
# 4         0.0  9.0  0.404233       2.135791    65.245574  1.461434   2.135791
# 5         0.0  9.0  0.160485       1.213505   128.204145  1.101592   1.213505
# 6         0.0  9.0  0.145905       1.412713   109.125201  1.188576   1.412713
# 7         0.0  9.0  0.290290       2.038108    79.442268  1.427623   2.038108
# 8         0.0  9.0  0.225420       1.510531   155.491170  1.229037   1.510531
# 9         0.0  9.0  0.152825       1.727463   156.281381  1.314330   1.727463
# 10        0.0  9.0  0.178199       2.128385   119.055819  1.458898   2.128385
# 11        0.0  9.0  0.156990       2.610154    96.437211  1.615597   2.610154
# 12        0.0  9.0  0.194641       1.221084   242.909402  1.105027   1.221084
# 13        0.0  9.0  0.177455       1.368112   217.193243  1.169663   1.368112
# 14        0.0  9.0  0.163072       1.731440   160.668737  1.315842   1.731440
# 15        0.0  9.0  0.147718       2.210195   116.184238  1.486673   2.210195
# 16        0.0  1.0  0.028928      26.345205    87.360294  5.132758  26.345205
# 17        0.0  1.0  0.035030      43.807182    36.037944  6.618699  43.807182
# 18        0.0  1.0  0.052408      52.907377    25.531521  7.273746  52.907377
#
#         xmin
# 0   1.533533
# 1   0.262988
# 2   1.008518
# 3   0.795724
# 4   0.533444
# 5   0.236869
# 6   0.217216
# 7   0.336495
# 8   0.377149
# 9   0.237887
# 10  0.243153
# 11  0.203196
# 12  0.290435
# 13  0.261083
# 14  0.220855
# 15  0.168755
# 16  0.274852
# 17  0.291314
# 18  0.690135
#
# [19 rows x 24 columns]
